# %%
from numpy import *
from GRpy.all import *
init_printing()
#init_printing(use_latex='mathjax')

# %%
t, x0, r, th, phi = symbols('t, x^0, r, theta, varphi',positive=True , real=True)
m,a = symbols('m,a', positive = True)
ut, omega, v, p2 = symbols('u_t, omega, v, p2', real=True)
M = Symbol('M', real=True)
s = Symbol('s', real=True)
S = Symbol('S', real=True)
uphi = Function(r'u^{\phi}')(s)
ur = Function(r'u^{r}')(s)
pphi = Symbol(r'p^{\phi}')
st = Function(r'S^t')(s)
sr = Function(r'S^r')(s)
stheta = Function(r'S^{\theta}')(s)
sphi = Function(r'S^{\phi}')(s)

# %%
sigma = r**2 + (a*cos(th))**2
delta = r**2 - 2*m*r + a**2

# %%
g = Metric((x0, r, th, phi))
g[-0,-0] = (1-(2*m*r/sigma))
g[-0,-1] = 0
g[-0,-2] = 0
g[-0,-3] = (2*a*m*r*sin(th)**2)/sigma
g[-1,-0] = 0
g[-1,-1] = -sigma/delta
g[-1,-2] = 0
g[-1,-3] = 0
g[-2,-0] = 0
g[-2,-1] = 0
g[-2,-2] = -sigma
g[-2,-3] = 0
g[-3,-0] = (2*a*m*r*sin(th)**2)/sigma
g[-3,-1] = 0
g[-3,-2] = 0
g[-3,-3] = -(r**2 +a**2 + (2*a**2*m*r*sin(th)**2)/sigma)*sin(th)**2

# %%
ginv = g.invert()
chris = Christoffel(g)
riem = Riemann(chris)

# %%
def dw(A,mu):
    downvector=0
    for nu in range(4):
        downvector += g.components[(-mu,-nu)]*A[nu]
    
    return simplify(downvector.subs(th,pi/2))

def down(A):
    return [dw(A,mu) for mu in range(4)]

def uw(A,mu):
    upvector=0
    for nu in range(4):
        upvector += ginv.components[(mu,nu)]*A[nu]
    
    return simplify(upvector.subs(th,pi/2))

def up(A):
    return [uw(A,mu) for mu in range(4)]

# %%
sup=[0,0,S/r,0]
pup=[pphi*(omega*r**3+a*m-a**2*m*omega-2*m*omega*r**2)/(m*(a**3*omega-a**2+3*a*omega*r**2-r**2)),0,0,pphi]

sdown=down(sup)
pdown=down(pup)

pup
# Out:
# ⎡          ⎛   2                    2      3⎞                 ⎤
# ⎢p__{\phi}⋅⎝- a ⋅m⋅ω + a⋅m - 2⋅m⋅ω⋅r  + ω⋅r ⎠                 ⎥
# ⎢────────────────────────────────────────────, 0, 0, p__{\phi}⎥
# ⎢         ⎛ 3      2          2    2⎞                         ⎥
# ⎣       m⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠                         ⎦

# %%
uupnonorm=[ut,ur,0,uphi]

N=0
for i in range(4):
    for j in range(4):
        N += g.components[(-i,-j)]*uupnonorm[i]*uupnonorm[j]
        
eq=1-N.subs(th,pi/2)

utnorm=solve(eq,ut)[1]
uphinorm=omega*utnorm
uup=[simplify(utnorm),0,0,simplify(uphinorm)]
udown=down(uup)

# %%
def lcup(i,j,k,l):
    return -LeviCivita(i,j,k,l)/(r**2)

def lcdown(i,j,k,l):
    return r**2*LeviCivita(i,j,k,l)

# %%
def ch(mu):
    ch=0
    for i in range(4):
        for j in range(4):
            ch += -chris.components[(i,-mu,-j)]*uup[j]*pdown[i]
        
    return simplify(ch.subs(th,pi/2))

def ls(mu):
    ls=0
    for nu in range(4):
        for gamma in range(4):
            for rho in range(4):
                for alpha in range(4):
                    for beta in range(4):
                        ls += -(-1/(2*M))*riem.components[(-nu,-gamma,-rho,-mu)].subs(th,pi/2)*lcup(nu,gamma,alpha,beta)*sdown[alpha]*pdown[beta]*uup[rho]
        
    return simplify(ls)

def dpmu(mu):
    return simplify(diff(pup[mu],s)+ch(mu)+ls(mu))

dpmu=[dpmu(0),dpmu(1),dpmu(2),dpmu(3)]

# %%
c2=0
for i in range(4):
    for j in range(4):
        for k in range(4):
            c2 += chris.components[(i,-j,-k)]*sdown[i]*uup[j]*uup[k]
            
def c3(mu):
    c=0
    for i in range(4):
        for j in range(4):
            c += chris.components[(mu,-i,-j)]*sup[i]*uup[j]
    
    return c

def dsmu(mu):
    A=c3(mu)+uup[mu]*c2
    B=simplify(A.subs(th,pi/2))
    return diff(sup[mu],s)+B
    
dsmu=[dsmu(0),dsmu(1),dsmu(2),dsmu(3)]

# %%
dpmu[0]
# Out:
# 0

# %%
dpmu[1]
# Out:
#           ⎛
#           ⎜      ⎛     2      2        2          2    3⎞
# p__{\phi}⋅⎝2⋅a⋅m⋅⎝- 2⋅a ⋅m + a ⋅r + 4⋅m ⋅r - 4⋅m⋅r  + r ⎠⋅u__{\phi}(s) + √r⋅(2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#            ___________________________________________________________________
#           ╱  6            2         4    2          2         4        4  3
# ⋅m - r)⋅╲╱  a ⋅r⋅u__{\phi} (s) - 6⋅a ⋅m⋅r ⋅u__{\phi} (s) - 2⋅a ⋅m + 3⋅a ⋅r ⋅u_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ______________________________________________________________________________
#        2       4         2  2  3          2         2  2         2    4
# _{\phi} (s) + a ⋅r + 12⋅a ⋅m ⋅r ⋅u__{\phi} (s) + 8⋅a ⋅m ⋅r - 12⋅a ⋅m⋅r ⋅u__{\p
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ______________________________________________________________________________
#    2         2    2       2         2    2      2  5          2       2  3
# hi} (s) - 2⋅a ⋅m⋅r ⋅u__{r} (s) - 8⋅a ⋅m⋅r  + 3⋅a ⋅r ⋅u__{\phi} (s) + a ⋅r ⋅u__
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ______________________________________________________________________________
#    2         2  3      3  4          2         3  2       2  5          2
# {r} (s) + 2⋅a ⋅r  - 8⋅m ⋅r ⋅u__{\phi} (s) - 8⋅m ⋅r  + 12⋅m ⋅r ⋅u__{\phi} (s) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ______________________________________________________________________________
#     2  3       2          2  3        6          2           4       2
#  4⋅m ⋅r ⋅u__{r} (s) + 12⋅m ⋅r  - 6⋅m⋅r ⋅u__{\phi} (s) - 4⋅m⋅r ⋅u__{r} (s) - 6⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# _____________________________________________⎞ ⎛
#    4    7          2       5       2       5 ⎟ ⎜       3 ⎛   2  2
# m⋅r  + r ⋅u__{\phi} (s) + r ⋅u__{r} (s) + r  ⎠⋅⎝2⋅M⋅m⋅r ⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2⎞ ⎛      ⎛    ⎛ 2                    2
# ⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝a⋅m⋅r⋅⎝2⋅a⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#       3⎞   ⎛   2       ⎛ 2    2⎞⎞ ⎛ 3      2          2    2⎞⎞         ⎛ 2
#  - ω⋅r ⎠ + ⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠⎠ + a⋅ω⋅r⋅⎝a  + 3
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2⎞ ⎛     2 ⎛ 3      2          2    2⎞             ⎛ 2                    2
# ⋅r ⎠⋅⎝2⋅a⋅m ⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠ + (2⋅m - r)⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#      3⎞⎞     ⎛    ⎛ 2                    2      3⎞   ⎛   2       ⎛ 2    2⎞⎞ ⎛
# - ω⋅r ⎠⎠ - ω⋅⎝2⋅a⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r  - ω⋅r ⎠ + ⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⋅⎝a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 3      2          2    2⎞⎞ ⎛   2  2             ⎛ 2      3⎞⎞     ⎛ 2    2⎞ ⎛
#  ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠⎠⋅⎝2⋅a ⋅m  - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ - r⋅⎝a  + r ⎠⋅⎝2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2 ⎛ 3      2          2    2⎞             ⎛ 2                    2      3⎞⎞
# a⋅m ⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠ + (2⋅m - r)⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r  - ω⋅r ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#       ⎛
# ⎞     ⎜     2   ⎛    ⎛ 2                    2      3⎞   ⎛   2       ⎛ 2    2⎞⎞
# ⎠ - S⋅⎝- a⋅m ⋅ω⋅⎝2⋅a⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r  - ω⋅r ⎠ + ⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  ⎛ 3      2          2    2⎞⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛
# ⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#           ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞     ⎛ 2            2⎞ ⎛
# r⋅(m - r)⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠ + r⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2       ⎛ 2    2⎞    3⎞     ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛
# - a ⋅m + m⋅⎝a  + r ⎠ + r ⎠ + 4⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2            2⎞   ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2
#   - 2⋅m⋅r + r ⎠ - ⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2            ⎞⎞      2   ⎛    ⎛ 2                    2      3⎞   ⎛   2       ⎛
#   + r⋅(m - r)⎠⎠ + a⋅m ⋅ω⋅⎝2⋅a⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r  - ω⋅r ⎠ + ⎝2⋅a ⋅m + r⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                        ⎛
#  2    2⎞⎞ ⎛ 3      2          2    2⎞⎞ ⎜   2  2  2 ⎛ 2      2⎞ ⎛ 2
# a  + r ⎠⎠⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠⎠⋅⎝2⋅a ⋅m ⋅r ⋅⎝a  + 3⋅r ⎠⋅⎝a  - 2⋅m⋅r + r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2⎞               ⎛   2 ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2
#  ⎠ + r⋅(2⋅m - r)⋅⎝2⋅a ⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#      2⎞   ⎛ 2      2⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2
# r + r ⎠ + ⎝a  + 3⋅r ⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#     2            ⎞     ⎛ 2      2⎞ ⎛ 2            2⎞ ⎛     2  2     ⎛   2
#  + r  + r⋅(m - r)⎠ + 2⋅⎝a  + 3⋅r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 4⋅a ⋅m  + m⋅⎝2⋅a ⋅m +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞   ⎛ 2      2⎞ ⎛ 2            2⎞ ⎛     2
# r⋅⎝a  + r ⎠⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ - ⎝a  + 3⋅r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 2⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2       ⎛ 2    2⎞             ⎛ 2      3⎞⎞⎞     ⎛   2  2             ⎛ 2
# m  + m⋅r⋅⎝a  + r ⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⎠ - 2⋅⎝2⋅a ⋅m  - (2⋅m - r)⋅⎝a ⋅m -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  3⎞⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2
# r ⎠⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r  + r⋅(m - r)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞     ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2⎞ ⎛     2
# ⎠ + 2⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 6⋅a ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                      ⎛
# 2       ⎛ 2      3⎞             ⎛   2      3⎞⎞     ⎛ 2            2⎞ ⎜   2  2
#   + 2⋅m⋅⎝a ⋅m - r ⎠ + (2⋅m - r)⋅⎝2⋅a ⋅m + r ⎠⎠ - 2⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝4⋅a ⋅m ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎛     2  2     ⎛   2       ⎛ 2    2⎞⎞              ⎛ 2      3⎞⎞
# ⎝- 4⋅a ⋅m  + m⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ - (-2⋅m + r)⋅⎝a ⋅m - r ⎠⎠ + 2⋅(2⋅m - r)⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎛ 2      3⎞ ⎛   2  2     ⎛   2       ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞   ⎛
# ⎝a ⋅m - r ⎠⋅⎝4⋅a ⋅m  - m⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ + ⎝2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                               2⎞⎞
#  2  2             ⎛ 2      3⎞⎞ ⎟⎟       ⎛   2  2             ⎛   2       ⎛ 2
# a ⋅m  - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ ⎠⎠ - a⋅m⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2⎞⎞⎞ ⎛     2 ⎛ 3      2          2    2⎞             ⎛ 2
#  r ⎠⎠⎠⋅⎝2⋅a⋅m ⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠ + (2⋅m - r)⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2      3⎞⎞ ⎛            ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞     ⎛   2
#   - ω⋅r ⎠⎠⋅⎝2⋅r⋅(m - r)⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠ + 4⋅⎝4⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2⎞   ⎛   2  2
# ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r ⎠ - ⎝4⋅a ⋅m  - (2⋅m -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2            ⎞   ⎛ 2            2⎞ ⎛
# r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r  + r⋅(m - r)⎠ + ⎝a  - 2⋅m⋅r + r ⎠⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                             ⎛    ⎛
#      2  2       ⎛ 2      2⎞             ⎛ 2      3⎞⎞⎞       ⎜    ⎜ 2    2 ⎛ 2
# - 2⋅a ⋅m  + m⋅r⋅⎝a  + 3⋅r ⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⎠ + a⋅m⋅⎝2⋅m⋅⎝a ⋅m⋅r ⋅⎝a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#      2⎞ ⎛ 2            2⎞      2   ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞
# + 3⋅r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠ + 2⋅a ⋅r⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞ ⎛ 2            2⎞     ⎛ 2    2⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞
# ⎠⋅⎝a  - 2⋅m⋅r + r ⎠ + r⋅⎝a  + r ⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                    ⎛
#  ⎛ 2            2            ⎞   ⎛ 2            2⎞ ⎜     2   ⎛   2  2     ⎛
# ⋅⎝a  - 2⋅m⋅r + r  + r⋅(m - r)⎠ - ⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 4⋅a ⋅m⋅⎝4⋅a ⋅m  - m⋅⎝2⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                              2
# 2       ⎛ 2    2⎞⎞              ⎛ 2      3⎞⎞      2 ⎛ 2    2⎞      ⎛   2
#  ⋅m + r⋅⎝a  + r ⎠⎠ + (-2⋅m + r)⋅⎝a ⋅m - r ⎠⎠ + m⋅r ⋅⎝a  + r ⎠  + 2⋅⎝2⋅a ⋅m + r
# ──────────────────────────────────────────────────────────────────────────────
#                                                                              2
#                      5           ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞
#               2⋅M⋅m⋅r ⋅(2⋅m - r)⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠
#
#                                                                         ⎞⎞
#  ⎛ 2    2⎞⎞ ⎛   2  2     ⎛   2       ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞⎟⎟
# ⋅⎝a  + r ⎠⎠⋅⎝4⋅a ⋅m  - m⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⎠⎠ - r
# ──────────────────────────────────────────────────────────────────────────────
#
#  ⎛ 2            2⎞ ⎛ 3      2          2    2⎞ ⎛     2      2        2
# ⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠⋅⎝- 2⋅a ⋅m + a ⋅r + 4⋅m ⋅r - 4⋅m
#
#
#  ⎛   2       ⎛ 2    2⎞⎞ ⎛  ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2
# ⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⋅⎝2⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#   2    3⎞
# ⋅r  + r ⎠
#
#
#          2⎞   ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2
# 2⋅m⋅r + r ⎠ + ⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#          ⎞   ⎛ 2            2⎞ ⎛     2  2       ⎛ 2    2⎞             ⎛ 2
# r⋅(m - r)⎠ - ⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 2⋅a ⋅m  + m⋅r⋅⎝a  + r ⎠ + (2⋅m - r)⋅⎝a ⋅m -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  3⎞⎞     ⎛ 2            2⎞ ⎛   2  2     ⎛   2       ⎛ 2    2⎞⎞             ⎛ 2
# r ⎠⎠ - 2⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝4⋅a ⋅m  - m⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ - (2⋅m - r)⋅⎝a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#           ⎞
#       3⎞⎞⎞⎟ ⎛     2 ⎛ 3      2          2    2⎞             ⎛ 2
# ⋅m - r ⎠⎠⎠⎠⋅⎝2⋅a⋅m ⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠ + (2⋅m - r)⋅⎝a ⋅m⋅ω - a⋅m + 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#      2      3⎞⎞    2 ⎛    ⎛ 2                    2      3⎞   ⎛   2       ⎛ 2
# m⋅ω⋅r  - ω⋅r ⎠⎠ + m ⋅⎝2⋅a⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r  - ω⋅r ⎠ + ⎝2⋅a ⋅m + r⋅⎝a  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2⎞⎞ ⎛ 3      2          2    2⎞⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞
#  r ⎠⎠⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞ ⎛   2     ⎛ 2            2⎞       ⎛ 2    2⎞ ⎛ 2            2⎞
# ⎠⋅⎝- a ⋅m⋅r⋅⎝a  - 2⋅m⋅r + r ⎠ + m⋅r⋅⎝a  + r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠ + 2⋅r⋅(m - r)⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞     ⎛   2  2             ⎛   2
# ⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠ + 4⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#     ⎛ 2    2⎞⎞⎞ ⎛ 2            2⎞   ⎛   2  2             ⎛   2       ⎛ 2    2⎞
# + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r ⎠ - ⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞⎞ ⎛ 2            2            ⎞⎞    2 ⎛    ⎛ 2                    2      3⎞
# ⎠⎠⋅⎝a  - 2⋅m⋅r + r  + r⋅(m - r)⎠⎠ + m ⋅⎝2⋅a⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r  - ω⋅r ⎠ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                      ⎛
#  ⎛   2       ⎛ 2    2⎞⎞ ⎛ 3      2          2    2⎞⎞ ⎜   2     ⎛  ⎛   2  2
#  ⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠⎠⋅⎝2⋅a ⋅m⋅r⋅⎝2⋅⎝4⋅a ⋅m  - (
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#          ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2⎞   ⎛   2  2             ⎛
# 2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r ⎠ + ⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2            ⎞   ⎛ 2            2⎞ ⎛     2
#  ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r  + r⋅(m - r)⎠ - ⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 2⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2       ⎛ 2    2⎞             ⎛ 2      3⎞⎞     ⎛ 2            2⎞ ⎛   2  2
# m  + m⋅r⋅⎝a  + r ⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ - 2⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝4⋅a ⋅m  - m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                               ⎛
#  ⎛   2       ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞⎞             ⎜ 2    2 ⎛ 2
# ⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⎠ - (2⋅m - r)⋅⎝a ⋅m⋅r ⋅⎝a  + 3
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2⎞ ⎛ 2            2⎞      2   ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛
# ⋅r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠ + 2⋅a ⋅r⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2            2⎞     ⎛ 2    2⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛
# a  - 2⋅m⋅r + r ⎠ + r⋅⎝a  + r ⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                 ⎛
# 2            2            ⎞   ⎛ 2            2⎞ ⎜     2   ⎛   2  2     ⎛   2
#   - 2⋅m⋅r + r  + r⋅(m - r)⎠ - ⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 4⋅a ⋅m⋅⎝4⋅a ⋅m  - m⋅⎝2⋅a ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                           2
#      ⎛ 2    2⎞⎞              ⎛ 2      3⎞⎞      2 ⎛ 2    2⎞      ⎛   2       ⎛
#  + r⋅⎝a  + r ⎠⎠ + (-2⋅m + r)⋅⎝a ⋅m - r ⎠⎠ + m⋅r ⋅⎝a  + r ⎠  + 2⋅⎝2⋅a ⋅m + r⋅⎝a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                      ⎞⎞⎞
# 2    2⎞⎞ ⎛   2  2     ⎛   2       ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞⎟⎟⎟     ⎛
#   + r ⎠⎠⋅⎝4⋅a ⋅m  - m⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⎠⎠⎠ + ω⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛     2 ⎛ 3      2          2    2
# 4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝2⋅a⋅m ⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞             ⎛ 2                    2      3⎞⎞ ⎛ 2  2   ⎛ 2      2⎞ ⎛ 2
# ⎠ + (2⋅m - r)⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r  - ω⋅r ⎠⎠⋅⎝a ⋅m ⋅r⋅⎝a  + 3⋅r ⎠⋅⎝a  - 2⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#       2⎞               ⎛ 2      3⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞
# ⋅r + r ⎠ + 2⋅r⋅(m - r)⋅⎝a ⋅m - r ⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞   ⎛ 2      3⎞ ⎛   2  2             ⎛ 2      3⎞⎞ ⎛ 2            2⎞   ⎛ 2
# ⎠ - ⎝a ⋅m - r ⎠⋅⎝2⋅a ⋅m  - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⋅⎝a  - 2⋅m⋅r + r ⎠ - ⎝a ⋅m -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  3⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2            ⎞
# r ⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r  + r⋅(m - r)⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    ⎛   2      3⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2
#  + ⎝4⋅a ⋅m - r ⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞⎞     ⎛     2 ⎛ 3      2          2    2⎞             ⎛ 2
# ⎠⎠ - ω⋅⎝2⋅a⋅m ⋅⎝a ⋅ω - a  + 3⋅a⋅ω⋅r  - r ⎠ + (2⋅m - r)⋅⎝a ⋅m⋅ω - a⋅m + 2⋅m⋅ω⋅r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#            ⎛
# 2      3⎞⎞ ⎜   2  2   ⎛   2 ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2
#   - ω⋅r ⎠⎠⋅⎝2⋅a ⋅m ⋅r⋅⎝2⋅a ⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#           2⎞   ⎛ 2      2⎞ ⎛   2  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2
#  2⋅m⋅r + r ⎠ + ⎝a  + 3⋅r ⎠⋅⎝4⋅a ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#          2            ⎞     ⎛ 2      2⎞ ⎛ 2            2⎞ ⎛     2  2     ⎛   2
# 2⋅m⋅r + r  + r⋅(m - r)⎠ + 2⋅⎝a  + 3⋅r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 4⋅a ⋅m  + m⋅⎝2⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#        ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞   ⎛ 2      2⎞ ⎛ 2            2⎞ ⎛
# ⋅m + r⋅⎝a  + r ⎠⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ - ⎝a  + 3⋅r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝-
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                            ⎛
#    2  2       ⎛ 2    2⎞             ⎛ 2      3⎞⎞⎞   ⎛   2       ⎛ 2    2⎞⎞ ⎜ 2
# 2⋅a ⋅m  + m⋅r⋅⎝a  + r ⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⎠ + ⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⋅⎝a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2  2 ⎛ 2      2⎞ ⎛ 2            2⎞   ⎛   2  2             ⎛ 2      3⎞⎞ ⎛   2
# ⋅m ⋅r ⋅⎝a  + 3⋅r ⎠⋅⎝a  - 2⋅m⋅r + r ⎠ - ⎝2⋅a ⋅m  - (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠⋅⎝4⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2            ⎞   ⎛   2
# ⋅m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r  + r⋅(m - r)⎠ + ⎝4⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2             ⎛   2       ⎛ 2    2⎞⎞⎞ ⎛ 2            2⎞ ⎛     2  2       ⎛ 2
# m  - (2⋅m - r)⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠⎠⋅⎝a  - 2⋅m⋅r + r ⎠⋅⎝- 6⋅a ⋅m  + 2⋅m⋅⎝a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                        ⎛
#      3⎞             ⎛   2      3⎞⎞   ⎛ 2            2⎞ ⎜   2  2 ⎛     2  2
# m - r ⎠ + (2⋅m - r)⋅⎝2⋅a ⋅m + r ⎠⎠ - ⎝a  - 2⋅m⋅r + r ⎠⋅⎝4⋅a ⋅m ⋅⎝- 4⋅a ⋅m  + m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  ⎛   2       ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞               ⎛ 2      3⎞ ⎛
# ⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ - 2⋅(2⋅m - r)⋅⎝a ⋅m - r ⎠⋅⎝-
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2  2     ⎛   2       ⎛ 2    2⎞⎞             ⎛ 2      3⎞⎞   ⎛   2  2
# 4⋅a ⋅m  + m⋅⎝2⋅a ⋅m + r⋅⎝a  + r ⎠⎠ + (2⋅m - r)⋅⎝a ⋅m - r ⎠⎠ + ⎝2⋅a ⋅m  - (2⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                  2⎞⎞⎞⎞⎞
#      ⎛ 2      3⎞⎞ ⎟⎟⎟⎟⎟
# - r)⋅⎝a ⋅m - r ⎠⎠ ⎠⎠⎠⎠⎠
# ───────────────────────

# %%
dpmu[2]
# Out:
# 0

# %%
dpmu[3]
# Out:
# 0

# %%
solve(dpmu[1],pphi)
# Out:
# [0]

# %%
simplify(solve(dpmu[1],uphi)[0])
# Out:
#          ___________________________________
#         ╱    2            2       2       2
#        ╱  - a  + 2⋅m⋅r - r ⋅u__{r} (s) - r
# √r⋅   ╱   ─────────────────────────────────
#      ╱              2            2
#    ╲╱              a  - 2⋅m⋅r + r
# ────────────────────────────────────────────
#              ____________________
#             ╱    2      2      3
#           ╲╱  2⋅a ⋅m + a ⋅r + r

# %%
dsmu
# Out:
# [0, 0, 0, 0]

# %%
condicion=0
for i in range(4):
    condicion += sup[i]*pdown[i]

# %% [markdown]
# La condución a satisfacer es:

# %%
simplify(condicion)
# Out:
# 0

# %%
del(ptheta)
ptheta = Symbol('p^theta', real=True)

pdownsol = [psol[0].rhs, psol[1].rhs, ptheta, psol[2].rhs]
pupsol=up(pdownsol)

# %%
def termino(mu):
    termino=0
    for nu in range(4):
        for alpha in range(4):
            for beta in range(4):
                for sigma in range(4):
                    for rho in range(4):
                        termino += lcup(mu,nu,alpha,beta)*chris.components[(rho,-nu,-sigma)]*udown[rho]*uup[sigma]*sdown[alpha]*udown[beta]
                        
    return termino

Masa=0
for mu in range(4):
    Masa += pupsol[mu]*udown[mu]

def p(mu):
    A=Masa*uup[mu]+termino(mu)
    return simplify(A.subs(th,pi/2))

momentum=[p(mu) for mu in range(4)]

# %%
pupsol[1], momentum[1]

# %%
pupsol[2], momentum[2]

# %% [markdown]
# De la componente $1$ o $r$ podemos notar que $C_2$ y $C_3$ en la solución del momentum deben ser 0 para que pueda satisfacerse la igualdad, mientras que de la componente $2$ o $\theta$ damos cuenta que para que $p^{\theta}$ es 0.
#
# Así, las soluciones para el momentum y el spín deben tener la forma:
# \begin{align}
# p_{\mu} &= [p^{\phi} \left( \frac{a^2 m \omega - am - \omega r^3}{m(a \omega - 1)} \right), 0, 0, p^{\phi}],\\
# S^{\mu} &= [0,0,\frac{S}{r},0].
# \end{align}

# %%
del(pphi)
pphi = Symbol('p^phi', real=True)

pmu=[pphi*(a**2*m*omega-a*m-omega*r**3)/(m*a*omega-m),0,0,pphi]

def t(mu):
    termino=0
    
    for nu in range(4):
        for alpha in range(4):
            for beta in range(4):
                for sigma in range(4):
                    for rho in range(4):
                        termino += lcup(mu,nu,alpha,beta)*chris.components[(rho,-nu,-sigma)]*udown[rho]*uup[sigma]*sdown[alpha]*udown[beta]
                        
    return termino
                        

Masa2=0
for mu in range(4):
    Masa2 += pmu[mu]*udown[mu]

def p2(mu):
    A=Masa2*uup[mu]+t(mu)
    return simplify(A.subs(th,pi/2))

pmu2=[p2(mu) for mu in range(4)]

# %%
0==pmu[1], pmu[1]==pmu2[1], 0==pmu[2], pmu[2]==pmu2[2]

# %% [markdown]
# De esta forma probamos que las componentes $r,\theta$ son iguales luego de aplicar la condición, ahora haremos lo mismo con las componentes $t,\phi$.

# %%
pmu[0],simplify(pmu2[0])

# %%
pmu[3],simplify(pmu2[3])

# %%
eq1=pmu[0]-simplify(pmu2[0])
eq2=pmu[3]-simplify(pmu2[3])
eqtotal=[eq1,eq2]

solve(eqtotal,[S,pphi])

# %% [markdown]
# Mostrando así que la componente $\phi$ del momentum y la componente $\theta$ del espín están relacionados como:

# %%
spin=solve(eq1, S)[0]
simplify(spin)
